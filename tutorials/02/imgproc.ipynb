# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import cv2

# %%
ydata = np.fromfile('0', dtype=np.uint8)

# %%
ydata.shape
# Out:
# (921600,)

# %%
yimg = ydata.reshape((720,1280))

# %%
plt.imshow(yimg)
plt.show()

# %%
udata = np.fromfile('1', dtype=np.uint8)
udata.shape
# Out:
# (230400,)

# %%
uimg = udata.reshape((360, 640))
plt.imshow(uimg)
plt.show()

# %%
vdata = np.fromfile('2', dtype=np.uint8)
vdata.shape
# Out:
# (230400,)

# %%
vimg = vdata.reshape((360, 640))
plt.imshow(vimg)
plt.show()

# %%
type(ydata)
# Out:
# numpy.ndarray

# %%
yuv_data = np.concatenate((ydata, udata, vdata))

# %%
yuv_data.shape
# Out:
# (1382400,)

# %%
w, h = width, height = 1280, 720

# %%
yuv_data.reshape((height*3//2, width))
yuv0 = yuv_data.shape

# %%
bgr0 = cv2.cvtColor(yuv0, cv2.COLOR_YUV2BGR_I420)
plt.imshow(bgr0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [21], in <module>
#       1 yuv_data.reshape((height*3//2, width))
#       2 yuv_data.shape
# ----> 3 bgr0 = cv2.cvtColor(yuv_data, cv2.COLOR_YUV2BGR_I420)
#       4 plt.imshow(bgr0)
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:108: error: (-215:Assertion failed) sz.width % 2 == 0 && sz.height % 3 == 0 in function 'CvtHelper'

# %%
fp = open("sample.yuv","wb")
yuv_data.tofile(fp);
fp.close()

# %% [markdown]
# ### YUV frame

# %%
# in YUV420 frame size in bytes is width*height*1.5
width * height + 2 * (width/2 * height/2), width * height * 3//2

# %%
outyuv = np.fromfile('out.yuv', dtype=np.uint8)

# %%
yuv_data1 = outyuv[:1382400]
((yuv_data - yuv_data1)**2)

# %% [markdown]
# ### display YUV frame

# %%
frame_size = width * height * 3//2

# %%
f = open('out.yuv', 'rb')

# %%
yuv = np.frombuffer(f.read(frame_size), dtype=np.uint8).reshape((height*3//2, width))
f.close()

# %%
yuv.shape, yuv.size

# %%
bgr = cv2.cvtColor(yuv, cv2.COLOR_YUV2BGR_I420)

# %%
plt.imshow(bgr)
